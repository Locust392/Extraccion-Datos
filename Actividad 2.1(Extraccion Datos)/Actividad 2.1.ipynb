# %%
#Importamos las librerias requeridas
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df= pd.read_excel('Detalle precios y productos fabricados 2022.xlsx')
df

# %% [markdown]
# FILTRO 1

# %%
#filtro por objeto
filtro1=df[(df["NOMBRE_CLIENTE"]== "ELICAMEX")]
filtro1
# Out:
#     CVE_DOC  FECHA_DOC NOMBRE_VENDEDOR NOMBRE_CLIENTE  CANT   CVE_ART  \
# 18   F37061 2022-01-05  ALFREDO CANELA       ELICAMEX     5  WRE-2133
# 19   F37061 2022-01-05  ALFREDO CANELA       ELICAMEX     7  WRE-2774
# 20   F37061 2022-01-05  ALFREDO CANELA       ELICAMEX     3  WRE-4885
# 286  F37564 2022-03-08  ALFREDO CANELA       ELICAMEX     5  WRE-2137
# 860  F38698 2022-07-29  ALFREDO CANELA       ELICAMEX     5  WRE-2774
#
#                                         DESCR  PRECIO_UNITARIO  \
# 18   BAN MICA 120mmØx50mm 850W 440V TTORNILLO           821.30
# 19    BAN MICA Ø120MM X 50 MM 700W 440V T TOR           821.30
# 20      BAN INOX 36MMØX25MM 150W 240V EXT30CM           496.35
# 286     BAN INOX 170MMØX55MM 1300W 440V C/STD          1103.00
# 860   BAN MICA Ø120MM X 50 MM 700W 440V T TOR           821.30
#
#      COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  \
# 18             0.00                     78.70           4106.50
# ...

# %%
filtro1.to_csv("Filtro por Objeto")

# %% [markdown]
# Filtro 2 Filas

# %%
#filtros por filas
#filtro2= df.iloc[0:8,:]    #filas consecutivas
filtro2= df.iloc[ [5,9], :] #filas no consecutivas
filtro2
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR      NOMBRE_CLIENTE  CANT  \
# 5  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ  PÚBLICO EN GENERAL     2
# 9  F37049 2022-01-05   DIEGO ARMANDO LEON DURAN  FIDEICOMISO F/1596     1
#
#     CVE_ART                                     DESCR  PRECIO_UNITARIO  \
# 5   BP00243     BAN P INOX 55MMX235MM 450W 127V T/TOR           237.07
# 9  TUE00207  TUB INCOLOY 1/2"Øx412mm J 9KW 240V PLACA          1615.00
#
#    COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  \
# 5           49.41                     49.41            474.14
# 9          517.89                    517.89           1615.00
#
#    COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO  MARGEN_TOTAL_CALCULADO
# 5                  98.82                     187.66                  375.32
# 9                 517.89                    1097.11                 1097.11

# %%
filtro2.to_csv("Filtro por Filas")

# %% [markdown]
# Filtro 3 Columnas

# %%
#filtro3=df.iloc[ : , 1:3]  #Columnas consecutivas
filtro3=df.iloc[ : , [0,3,5]]   #Columnas no consecutivas
filtro3
# Out:
#      CVE_DOC                NOMBRE_CLIENTE       CVE_ART
# 0     F37034            PÚBLICO EN GENERAL      TUE00244
# 1     F37036  JUAN ANTONIO RESENDIZ UGALDE      TUA00028
# 2     F37041     ANA BARBARA CRUZ PALACIOS        TP0007
# 3     F37042          OMAR RODRIGUEZ GOMEZ        TP0001
# 4     F37043            PÚBLICO EN GENERAL       BP00242
# ...      ...                           ...           ...
# 1421  F39834     LUIS ENRIQUE PATIÑO PEREZ  CS12F1040A00
# 1422  F39834     LUIS ENRIQUE PATIÑO PEREZ  CS12H1050A00
# 1423  F39835          SEVEN DAYS ALL SPORT      TUE00394
# 1424  F39837           REVUELTA MONTECARLO      TUA00470
# 1425  F39838                CPEG SOLUTIONS       RB00007
#
# [1426 rows x 3 columns]

# %%
filtro3.to_csv("Filtro por Columnas")

# %% [markdown]
# Filtro 4 Filas vs Columnas

# %%
df1= pd.read_excel('Detalle precios y productos fabricados 2022.xlsx', index_col=2)
df
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3             OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4               PÚBLICO EN GENERAL     2       BP00242
# ...

# %%
#paso 2: aplicaciones filtro de filas vs columnas
filtro4=df1.loc[["DIEGO ARMANDO LEON DURAN", "ALFREDO CANELA"], ["CANT"]]
filtro4
# Out:
#                           CANT
# NOMBRE_VENDEDOR
# DIEGO ARMANDO LEON DURAN     7
# DIEGO ARMANDO LEON DURAN     1
# DIEGO ARMANDO LEON DURAN     1
# DIEGO ARMANDO LEON DURAN     1
# DIEGO ARMANDO LEON DURAN     1
# ...                        ...
# ALFREDO CANELA              10
# ALFREDO CANELA               1
# ALFREDO CANELA               1
# ALFREDO CANELA               6
# ALFREDO CANELA               1
#
# [455 rows x 1 columns]

# %%
filtro4.to_csv("Filtro Filas vs Columnas")

# %% [markdown]
# Filtro 5 Por cabecera

# %%
filtro5=df.head()
filtro5
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR                NOMBRE_CLIENTE  \
# 0  F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# 1  F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ  JUAN ANTONIO RESENDIZ UGALDE
# 2  F37041 2022-01-05   DIEGO ARMANDO LEON DURAN     ANA BARBARA CRUZ PALACIOS
# 3  F37042 2022-01-05   DIEGO ARMANDO LEON DURAN          OMAR RODRIGUEZ GOMEZ
# 4  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
#
#    CANT   CVE_ART                                    DESCR  PRECIO_UNITARIO  \
# 0     1  TUE00244  TUB COBRE 5/16"ØX165MM CIRCULA1.5KW127V           434.48
# 1     1  TUA00028  TUA U" 5/16 ØX250MM 1200W 120V TAP1"NPT          1264.05
# 2     7    TP0007     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 7 MT           551.61
# 3     1    TP0001     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 1 MT           140.00
# 4     2   BP00242  BAN P INOX 115MMX235MM 1000W 127V T/TOR           172.41
#
# ...

# %%
filtro5.to_csv("Filtro Cabecera")

# %% [markdown]
# Filtro 6 Por Cola

# %%
filtro6=df.tail()
filtro6
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR             NOMBRE_CLIENTE  \
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ       SEVEN DAYS ALL SPORT
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ        REVUELTA MONTECARLO
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA             CPEG SOLUTIONS
#
#       CANT       CVE_ART                                     DESCR  \
# 1421     6  CS12F1040A00      CAS INOX 1/2"ØX3" 400W 127V EXT.30CM
# 1422     6  CS12H1050A00       CAS INOX 1/2"ØX4" 500W 127V EXT30CM
# 1423     3      TUE00394  TUB INOX 5/16"ØX300MM 5300W 220V "M" ESP
# 1424     1      TUA00470  TUB INOX 1/2"ØX500MM 10KW 220V 2 1/2"NPT
# 1425    10       RB00007   FAB  BOBINA DSD1 6 COLOCAR B/NUEVA 488V
#
#       PRECIO_UNITARIO  COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  \
# ...

# %%
filtro6.to_csv("Filtro por Cola")

# %% [markdown]
# Filtro por Comparacion

# %%
filtro7=df[df["CANT"] >= 6]
filtro7
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR             NOMBRE_CLIENTE  \
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN  ANA BARBARA CRUZ PALACIOS
# 19    F37061 2022-01-05             ALFREDO CANELA                   ELICAMEX
# 27    F37073 2022-01-07  LETICIA RAMIREZ HERNANDEZ      KARINA AGUILAR TORRES
# 29    F37078 2022-01-07             ALFREDO CANELA      CLAVOS NACIONALES C.N
# 30    F37083 2022-01-10             ALFREDO CANELA  PEDRO ANTONIO SOTO IBARRA
# ...      ...        ...                        ...                        ...
# 1409  F39816 2022-12-22             ALFREDO CANELA             TOSTADAS FANNY
# 1415  F39830 2022-12-23  LETICIA RAMIREZ HERNANDEZ                     TORJJS
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA             CPEG SOLUTIONS
#
# ...

# %%
filtro7.to_csv("Filtro por Comparacion")

# %% [markdown]
# Filtros Basicos con Conectores Logicos

# %%
#Filtro Y
filtro8=df[(df["CANT"] <6) & (df["CVE_ART"] == "TUE00322")]
filtro8
# Out:
#    CVE_DOC  FECHA_DOC           NOMBRE_VENDEDOR          NOMBRE_CLIENTE  CANT  \
# 46  F37117 2022-01-14  DIEGO ARMANDO LEON DURAN  APLICACIONES SILIDRIEL     2
#
#      CVE_ART                                     DESCR  PRECIO_UNITARIO  \
# 46  TUE00322  TUB INOX 7/16"ØX410MM 2500W220V CIRCULAR           785.25
#
#     COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  \
# 46          181.88                    181.88            1570.5
#
#     COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO  MARGEN_TOTAL_CALCULADO
# 46                 363.75                     603.38                 1206.75

# %%
filtro8.to_csv("filtro Conector Y")

# %% [markdown]
# Filtro O

# %%
filtro9=df[(df["CANT"] < 10) | (df["CVE_ART"]== "TUE00207")]
filtro9
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1420  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3             OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4               PÚBLICO EN GENERAL     2       BP00242
# ...

# %%
filtro9.to_csv("Filtro O")

# %% [markdown]
# Filtro NOT

# %%
filtro10=df[~(df["NOMBRE_VENDEDOR"]=="DIEGO ARMANDO LEON DURAN")]
filtro10
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 7     F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 4               PÚBLICO EN GENERAL     2       BP00242
# 5               PÚBLICO EN GENERAL     2       BP00243
# 7        ANA BARBARA CRUZ PALACIOS     3        TP0001
# ...

# %%
filtro10.to_csv("Filtro NOT")
